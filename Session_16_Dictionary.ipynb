# %%
name=['ramesh','suresh','mahesh']
age=[20,22,24]
# ramesh age is 20
# suresh age is 22
# mahesh age is 24
for i in name:
    for j in age:
        print(f'{i} age is {j}')
# Out:
# ramesh age is 20
# ramesh age is 22
# ramesh age is 24
# suresh age is 20
# suresh age is 22
# suresh age is 24
# mahesh age is 20
# mahesh age is 22
# mahesh age is 24

# %%
for i in range(len(name)):
    #print(name[i],age[i])
    print(f'the {name[i]} age is :{age[i]}')
# Out:
# the ramesh age is :20
# the suresh age is :22
# the mahesh age is :24

# %% [markdown]
# ### zip

# %%
name=['ramesh','suresh','mahesh']
age=[20,22,24]
# thes two lists are together
# ramesh  is related with 20 
#

# %%
for i,j in zip(name,age):
    print(f'{i} age is:{j}')
# Out:
# ramesh age is:20
# suresh age is:22
# mahesh age is:24

# %% [markdown]
# ### pair concept

# %% [markdown]
# - distionary is concept related pair the items
#
# - it is represent with curly braces : {}
#
# - two items : key and value
#
# - distionary is called as {key:values} pair

# %%
dict(zip(name,age))
# Out:
# {'ramesh': 20, 'suresh': 22, 'mahesh': 24}

# %%
d={'ramesh': 20, 'suresh': 22, 'mahesh': 24}
d
# Out:
# {'ramesh': 20, 'suresh': 22, 'mahesh': 24}

# %%
# in avobe keys are : 'ramesh','suresh','mahesh'
#          valus are : 20,22,24

# %% [markdown]
# ### Intialization

# %%
d1={'ramesh': 20, 'suresh': 22, 'mahesh': 24}
d2={20:'ramesh', 22:'suresh', 24 :'mahesh'}
d2
# Out:
# {20: 'ramesh', 'suresh': 22, 'mahesh': 24}

# %%
d11={'ramseh':[20,30,40]}
d11
# Out:
# {'ramseh': [20, 30, 40]}

# %%
d12={'ramseh':{20}}
d12
# Out:
# {'ramseh': {20}}

# %%
d13={'ramseh':20.3,'suresh':8.9}
d13
# Out:
# {'ramseh': 20.3, 'suresh': 8.9}

# %%
d14={'ramseh':'ramesh','suresh':'suresh'}
d14
# Out:
# {'ramseh': 'ramesh', 'suresh': 'suresh'}

# %%
d15={'ramseh':('suresh','ramesh')}
d15
# Out:
# {'ramseh': ('suresh', 'ramesh')}

# %%
d16={'ramesh':True}
d16
# Out:
# {'ramesh': True}

# %%
d17={'ramesh':20,'ramesh':22}
d17
# Out:
# {'ramesh': 22}

# %%
d18={'ramesh':20,20:'suresh','sati':True,False:True}
d18
# Out:
# {'ramesh': 20, 20: 'suresh', 'sati': True, False: True}

# %%
d19={{'ramesh':20}:21}
d19
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 d19={{'ramesh':20}:21}
#       2 d19
#
# TypeError: unhashable type: 'dict'

# %%
d20={20:'ramesh',20:'suresh'}
d20
# Out:
# {20: 'suresh'}

# %%
d21={'20':'ramesh','21':'suresh'}
d21
# Out:
# {'20': 'ramesh', '21': 'suresh'}

# %%
d22={'20':'ramesh','20':'suresh'}
d22
# Out:
# {'20': 'suresh'}

# %%
d23={('ramesh','suresh'):'20'}
d23
# Out:
# {('ramesh', 'suresh'): '20'}

# %% [markdown]
# ### IMP Note- keys are important

# %%
d111={'ramesh': 20, 'suresh': 22, 'mahesh': 24}

# %%
sorted(d111)
# Out:
# ['mahesh', 'ramesh', 'suresh']

# %%
list(reversed(d111))
# Out:
# ['mahesh', 'suresh', 'ramesh']

# %%
d222={20: 'ramesh',22: 'suresh',24:'mahesh'}
min(d222)
# Out:
# 20

# %%
max(d222)
# Out:
# 24

# %%
sum(d222)
# Out:
# 66

# %%
sorted(d222)
# Out:
# [20, 22, 24]

# %%
list(reversed(d222))
# Out:
# [24, 22, 20]

# %%
dist5={'Ramesh':20,'Ramesh':22}  # latest value 
dist6={'Ramesh':20,'Ramesh':20}  # one value
dist7={'Ramesh':20,'suresh':20}  #

# %%
{<list>:<values>}  # fail mutable
{<tuple>:<values>}  # works immutable
{<dict>:<values>}   # fail mutable

# %% [markdown]
# - understand the past data when new data come predict the answer is call michine lerning

# %% [markdown]
# ### concatetion

# %%
dist12={'Ramesh':20,'Ramesh':22} 
dist13={'Ramesh':21,'Ramesh':20}
dist12+dist13
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 dist12={'Ramesh':20,'Ramesh':22}
#       2 dist13={'Ramesh':21,'Ramesh':20}
# ----> 3 dist12+dist13
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
dict1={'ramesh': 20, 'suresh': 22, 'mahesh': 24}
for i in dict1:
    print(i)
# Out:
# ramesh
# suresh
# mahesh

# %% [markdown]
# ### Index

# %%
dict1={'ramesh': 20, 'suresh': 22, 'mahesh': 24}
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 2
#       1 dict1={'ramesh': 20, 'suresh': 22, 'mahesh': 24}
# ----> 2 dict1[0]
#
# KeyError: 0

# %%
dict1={'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}
dict1['Ramesh']
# dict1[<keys>] then value will come
# Out:
# 20

# %%
dict1['Mahesh']
# Out:
# 24

# %%
for i in dict1:
    print(i,dict1[i])
    print(f'{i} age is:{dict1[i]}')
# Out:
# Ramesh 20
# Ramesh age is:20
# Suresh 22
# Suresh age is:22
# Mahesh 24
# Mahesh age is:24

# %% [markdown]
# ### Empty dictionary

# %%
s=''
s=s+'a'
s
# Out:
# 'a'

# %%
l=[]
l.append(20)
l
# Out:
# [20]

# %%
d={}
d['Ramesh']=20
d['Suresh']=22
d
# Out:
# {'Ramesh': 20, 'Suresh': 22}

# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,30,40]
d={}
for i,j in zip(names,age):
    d[i]=j
d
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}

# %%
s='hai how are you'
s.split()
# Out:
# ['hai', 'how', 'are', 'you']

# %%
dict1={'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}
names=[]
age=[]
for kesy in dict1:
    names.append(kesy)
    age.append(dict1[kesy])
    
print(names)
print(age)
# Out:
# ['Ramesh', 'Suresh', 'Mahesh']
# [20, 30, 40]

# %% [markdown]
# ### mutable- immutable

# %% [markdown]
# - we need to change the value of specific key then it is consider as a mutable

# %%
{'Ramesh':20,'Ramesh':24}
# Out:
# {'Ramesh': 24}

# %%
d={}
d['Ramesh']=24
d
# Out:
# {'Ramesh': 24}

# %%
d['Ramesh']=34
d
# Out:
# {'Ramesh': 34}

# %%
dict1={'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}

# %%
dict1['Mahesh']=50
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Mahesh': 50}

# %%
dict1[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 dict1[0:2]
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# #### slice is not possible because in Dictionary only key-value concept

# %%
dict1={'fruites':'apple'}
dict1['fruites']
# Out:
# 'apple'

# %%
dict1={'fruites':['apple']}
dict1['fruites']
# Out:
# ['apple']

# %%
dict1={'fruites':['apple']}
dict1['fruites'][0]
# Out:
# 'apple'

# %%
dict1={'fruites':['apple','cherry']}
dict1['fruites'][1]
# Out:
# 'cherry'

# %%
dict1={'fruites':['apple','cherry','banana'],
      'cost':[20,5,2]}
# Which is the lowest cost that item should come
# step-1: extract cost list
# step-2: apply min (list) 2
# step-3: extract the index using list.index(min): id=2
# step-4: extract the fruite list
# step-5: apply the id
MIN=min(dict1['cost'])
ID=(dict1['cost']).index(MIN)
dict1['fruites'][ID]
# Out:
# 'banana'

# %%
d={'fruites':[{'items':['apple','cherry']}]}
f=d['fruites'][0]
g=f['items'][1]
g
# Out:
# 'cherry'

# %%
d={'fruites':{'items':'apple'}}
d['fruites']['items']
# Out:
# 'apple'

# %%
d={'Fruites':[{'items':[{'orange':
                         [{'Nagpur':
                           [{'MH':
                             [{'king':
                               [{'shivaji':
                                 [{'son':
                                   [{'shambaji':
                                     [{'chava':'viky'}]}]}
                                 ]}]}]}]}
                         ]}
                       ]}
             ]}
d
# Out:
# {'Fruites': [{'items': [{'orange': [{'Nagpur': [{'MH': [{'king': [{'shivaji': [{'son': [{'shambaji': [{'chava': 'viky'}]}]}]}]}]}]}]}]}]}

# %%
d['Fruites'][0]['items'][0]['orange'][0]['Nagpur'][0]['MH'][0]['king'][0]['shivaji'][0]['son'][0]['shambaji'][0]['chava']
# Out:
# 'viky'

# %% [markdown]
# ### methods

# %%
dir(dict1)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
'clear',
 'copy',
 'fromkeys',
 'get',
 'items',
 'keys',
 'pop',
 'popitem',
 'setdefault',
 'update',
 'values']

# %%
dict1={'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}
dict1.clear()
dict1
# Out:
# {}

# %%
dict1={'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}
dict1.copy()
dict2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 2
#       1 dict1={'Ramesh': 20, 'Suresh': 30, 'Mahesh': 40}
# ----> 2 dict1.copy(dict2)
#       3 dict2
#
# NameError: name 'dict2' is not defined
